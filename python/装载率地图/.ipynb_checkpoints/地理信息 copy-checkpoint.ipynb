# %%
import folium
import pandas as pd

# define the world map
world_map = folium.Map()

# display world map
world_map

latitude = 12.6985352
longitude = 99.7649053

# Create map and display it
san_map = folium.Map(location=[latitude, longitude], zoom_start=6)
# Display the map 
san_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data2=pd.read_csv(r"D:\Onedrive\68，地理信息\15hub.csv")
# add pop-up text to each marker on the map
latitudes = list(data2.lat)
longitudes = list(data2.lng)
labels = list(data2.name)

for lat, lng, label in zip(latitudes, longitudes, labels):
    folium.Marker([lat, lng], popup=label).add_to(san_map)    
san_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data3=pd.read_excel(r"D:\Onedrive\68，地理信息\HUB间装载率地图\HUB间装载率信息.xlsx")

# %%
data3
# Out:
#     groupid                   store1       lat1        lng1  \
# 0         3    02 NE1_HUB-นครราชสีมา  14.930258  102.132909
# 1         5  03 SO1_HUB-สุราษฏร์ธานี   9.118142   99.292152
# 2         6    02 NE1_HUB-นครราชสีมา  14.930258  102.132909
# 3         9     04 NO1_HUB-นครสวรรค์  15.632067  100.127893
# 4        10     04 NO1_HUB-นครสวรรค์  15.632067  100.127893
# 5        12  03 SO1_HUB-สุราษฏร์ธานี   9.118142   99.292152
# 6        18    02 NE1_HUB-นครราชสีมา  14.930258  102.132909
# 7        20         05 LAS_HUB-ลาซาล  13.650154  100.647259
# 8        24         05 LAS_HUB-ลาซาล  13.650154  100.647259
# 9        40     04 NO1_HUB-นครสวรรค์  15.632067  100.127893
# 10       48         05 LAS_HUB-ลาซาล  13.650154  100.647259
# 11       65         CNX_DC-เชียงใหม่  18.742318   99.007807
# 12       72     04 NO1_HUB-นครสวรรค์  15.632067  100.127893
# 13       80         05 LAS_HUB-ลาซาล  13.650154  100.647259
# 14      136     04 NO1_HUB-นครสวรรค์  15.632067  100.127893
# 15      144         05 LAS_HUB-ลาซาล  13.650154  100.647259
# 16      160         06 LPT_HUB-ลำปาง  18.179995   99.410626
# 17      258     09 KKC_HUB - ขอนแก่น  16.400216  102.871005
# 18      272     09 KKC_HUB - ขอนแก่น  16.400216  102.871005
# 19      513      10 NE3_HUB-อุดรธานี  17.124802  102.944257
# 20      514      10 NE3_HUB-อุดรธานี  17.124802  102.944257
# 21      528      10 NE3_HUB-อุดรธานี  17.124802  102.944257
# 22     1026       UBP_DC-อุบลราชธานี  15.196337  104.848005
# 23     1040       UBP_DC-อุบลราชธานี  15.196337  104.848005
# 24     2064         05 LAS_HUB-ลาซาล  13.650154  100.647259
# 25     4097             CJM_DC-ชุมพร  10.489755   99.122687
# 26     4112         05 LAS_HUB-ลาซาล  13.650154  100.647259
# 27     8193             YAS_DC-ยโสธร  15.808297  104.160520
# 28     8194    02 NE1_HUB-นครราชสีมา  14.930258  102.132909
# 29     8208         05 LAS_HUB-ลาซาล  13.650154  100.647259
# 30     8448             YAS_DC-ยโสธร  15.808297  104.160520
#
#                      store2       lat2        lng2  loadrate   color    pkg  \
# 0        01 BKK_HUB-จตุโชติ  13.651285  100.648434  0.171783   green   7206
# 1        01 BKK_HUB-จตุโชติ  13.651285  100.648434  0.367971   green   8725
# 2   03 SO1_HUB-สุราษฏร์ธานี   9.118142   99.292152  0.776536     red  35068
# 3        01 BKK_HUB-จตุโชติ  13.651285  100.648434  0.409286  orange  10794
# 4     02 NE1_HUB-นครราชสีมา  14.930258  102.132909  1.209879     red  59237
# 5      04 NO1_HUB-นครสวรรค์  15.632067  100.127893  0.730021     red  30458
# 6          05 LAS_HUB-ลาซาล  13.650154  100.647259  0.634824  orange  83033
# 7   03 SO1_HUB-สุราษฏร์ธานี   9.118142   99.292152  0.723803     red  97637
# 8      04 NO1_HUB-นครสวรรค์  15.632067  100.127893  0.687611  orange  96606
# 9          06 LPT_HUB-ลำปาง  18.179995   99.410626  0.584522  orange  15672
# 10         06 LPT_HUB-ลำปาง  18.179995   99.410626  0.518571  orange  25829
# 11       01 BKK_HUB-จตุโชติ  13.651285  100.648434  0.246471   green   6699
# 12         CNX_DC-เชียงใหม่  18.742318   99.007807  0.720150     red  33365
# 13         CNX_DC-เชียงใหม่  18.742318   99.007807  0.733376     red  57900
# 14          CEI_DC-เชียงราย  19.866592   99.844869  0.548064  orange  16185
# 15          CEI_DC-เชียงราย  19.866592   99.844869  0.552457  orange  27463
# 16          CEI_DC-เชียงราย  19.866592   99.844869  0.568007  orange   3822
# 17    02 NE1_HUB-นครราชสีมา  14.930258  102.132909  0.655421  orange  33853
# 18         05 LAS_HUB-ลาซาล  13.650154  100.647259  0.538948  orange  44765
# 19       01 BKK_HUB-จตุโชติ  13.651285  100.648434  0.138471   green   4201
# 20    02 NE1_HUB-นครราชสีมา  14.930258  102.132909  0.670614  orange  31212
# 21         05 LAS_HUB-ลาซาล  13.650154  100.647259  0.524725  orange  55343
# 22    02 NE1_HUB-นครราชสีมา  14.930258  102.132909  0.713554     red  15398
# 23         05 LAS_HUB-ลาซาล  13.650154  100.647259  0.387664   green  22233
# 24     12 SO2_HUB - หาดใหญ่   6.923779  100.470471  0.493581  orange  35302
# 25       01 BKK_HUB-จตุโชติ  13.651285  100.648434  0.130543   green   3024
# 26             CJM_DC-ชุมพร  10.489755   99.122687  0.625886  orange  11738
# 27       01 BKK_HUB-จตุโชติ  13.651285  100.648434  0.327000   green   1057
# 28             YAS_DC-ยโสธร  15.808297  104.160520  0.442993  orange  18884
# 29             YAS_DC-ยโสธร  15.808297  104.160520  0.469482  orange  28647
# 30     09 KKC_HUB - ขอนแก่น  16.400216  102.871005  0.460386  orange   4190
#
#     base     weight  touming
# 0   1057   1.363482      0.3
# 1   1057   1.650899      0.3
# 2   1057   6.635383      0.3
# 3   1057   2.042384      0.3
# 4   1057  11.208515      0.3
# 5   1057   5.763103      0.3
# 6   1057  15.711069      0.3
# 7   1057  18.474361      0.3
# 8   1057  18.279281      0.3
# 9   1057   2.965374      0.3
# 10  1057   4.887228      0.3
# 11  1057   1.267550      0.3
# 12  1057   6.313150      0.3
# 13  1057  10.955535      0.3
# 14  1057   3.062441      0.3
# 15  1057   5.196405      0.3
# 16  1057   0.723179      0.3
# 17  1057   6.405487      0.3
# 18  1057   8.470199      0.3
# 19  1057   0.794891      0.3
# 20  1057   5.905771      0.3
# 21  1057  10.471712      0.3
# 22  1057   2.913529      0.3
# 23  1057   4.206812      0.3
# 24  1057   6.679659      0.3
# 25  1057   0.572185      0.3
# 26  1057   2.221003      0.3
# 27  1057   0.200000      0.3
# 28  1057   3.573132      0.3
# 29  1057   5.420435      0.3
# 30  1057   0.792810      0.3

# %%
weizhi=[]
for x in data3.index:
    a=[[data3.lat1.loc[x],data3.lng1.loc[x]],[data3.lat2.loc[x],data3.lng2.loc[x]]]
    weizhi.append(a)
colorr=[]
for y in data3.index:
    b=[data3.color.loc[y]]
    colorr.append(b)
weightt=[]
for z in data3.index:
    c=[data3.weight.loc[z]]
    weightt.append(c)
touming=[]
for i in data3.index:
    d=[data3.touming.loc[i]]
    touming.append(d)

# %%
colorr=[]
for x in data3.index:
    b=[data3.color.loc[x]]
    colorr.append(b)

# %%
weightt=[]
for x in data3.index:
    b=[data3.weight.loc[x]]
    weightt.append(b)

# %%
for weizhi,colorr,weightt in zip(weizhi,colorr,weightt):
    folium.PolyLine(weizhi,color=colorr, weight=weightt, opacity=0.1).add_to(san_map)
san_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mylist

folium.PolyLine(points_a, color="green", weight=2.5, opacity=1).add_to(my_map)
folium.PolyLine(points_z, color="blue", weight=2.5, opacity=1).add_to(my_map)
# Out:
# [([[[14.930258], [102.132909]], [[13.651285], [100.648434]]],
#   'green',
#   8180,
#   0.6),
#  ([[[9.118142], [99.292152]], [[13.651285], [100.648434]]],
#   'green',
#   8060,
#   0.6),
#  ([[[14.930258], [102.132909]], [[9.118142], [99.292152]]], 'red', 35308, 0.6),
#  ([[[15.632067], [100.127893]], [[13.651285], [100.648434]]],
#   'orange',
#   10770,
#   0.6),
#  ([[[14.930258], [102.132909]], [[15.632067], [100.127893]]],
#   'red',
#   58567,
#   0.6),
#  ([[[9.118142], [99.292152]], [[15.632067], [100.127893]]], 'red', 30261, 0.6),
#  ([[[13.651285], [100.648434]], [[13.650154], [100.647259]]],
#   'orange',
#   16627,
#   0.6),
#  ([[[14.930258], [102.132909]], [[13.650154], [100.647259]]],
#   'orange',
#   86689,
#   0.6),
#  ([[[9.118142], [99.292152]], [[13.650154], [100.647259]]],
#   'orange',
#   99617,
#   0.6),
#  ([[[15.632067], [100.127893]], [[13.650154], [100.647259]]],
#   'orange',
#   96046,
#   0.6),
#  ([[[15.632067], [100.127893]], [[18.264286], [99.464213]]],
#   'orange',
#   4176,
#   0.6),
#  ([[[18.742318], [99.007807]], [[13.651285], [100.648434]]],
#   'green',
#   6265,
#   0.6),
#  ([[[15.632067], [100.127893]], [[18.742318], [99.007807]]],
#   'red',
#   32602,
#   0.6),
#  ([[[13.650154], [100.647259]], [[18.742318], [99.007807]]],
#   'red',
#   57656,
#   0.6),
#  ([[[15.632067], [100.127893]], [[19.866592], [99.844869]]],
#   'orange',
#   16352,
#   0.6),
#  ([[[13.650154], [100.647259]], [[19.866592], [99.844869]]],
#   'orange',
#   27382,
#   0.6),
#  ([[[14.930258], [102.132909]], [[15.196337], [104.848005]]],
#   'red',
#   16429,
#   0.6),
#  ([[[13.650154], [100.647259]], [[15.196337], [104.848005]]],
#   'green',
#   21551,
#   0.6),
#  ([[[9.118142], [99.292152]], [[7.015955], [100.432666]]], 'red', 40195, 0.6),
#  ([[[9.118142], [99.292152]], [[7.859939], [98.355066]]],
#   'orange',
#   30097,
#   0.6),
#  ([[[10.489755], [99.122687]], [[13.651285], [100.648434]]],
#   'green',
#   3252,
#   0.6),
#  ([[[13.650154], [100.647259]], [[10.489755], [99.122687]]],
#   'orange',
#   10851,
#   0.6),
#  ([[[15.808297], [104.16052]], [[13.651285], [100.648434]]],
#   'green',
#   1057,
#   0.6),
#  ([[[14.930258], [102.132909]], [[15.808297], [104.16052]]],
#   'orange',
#   19139,
#   0.6),
#  ([[[13.650154], [100.647259]], [[15.808297], [104.16052]]],
#   'orange',
#   44356,
#   0.6)]

# %%
san_map.save("./lines_withmarker.html")
